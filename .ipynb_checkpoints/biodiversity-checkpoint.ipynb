# %% [markdown]
# ## Biodiversity in National Parks

# %%
# Get Descriptive Statistics for each dataset
print(observations.describe())
print(species.describe())
# Out:
#        observations
# count  23296.000000
# mean     142.287904
# std       69.890532
# min        9.000000
# 25%       86.000000
# 50%      124.000000
# 75%      195.000000
# max      321.000000
#               category scientific_name   common_names conservation_status
# count             5824            5824           5824                 191
# unique               7            5541           5504                   4
# top     Vascular Plant  Holcus lanatus  Dicranum Moss  Species of Concern
# freq              4470               3              7                 161

# %%
# Read in Data and Check columns | Import necessary libraries

import pandas as pd
import numpy as np
import seaborn as sns

observations = pd.read_csv('observations.csv')
species = pd.read_csv('species_info.csv')

print(observations.head())
# Out:
#             scientific_name                            park_name  observations
# 0        Vicia benghalensis  Great Smoky Mountains National Park            68
# 1            Neovison vison  Great Smoky Mountains National Park            77
# 2         Prunus subcordata               Yosemite National Park           138
# 3      Abutilon theophrasti                  Bryce National Park            84
# 4  Githopsis specularioides  Great Smoky Mountains National Park            85

# %%
print(species.head())
# Out:
#   category                scientific_name  \
# 0   Mammal  Clethrionomys gapperi gapperi
# 1   Mammal                      Bos bison
# 2   Mammal                     Bos taurus
# 3   Mammal                     Ovis aries
# 4   Mammal                 Cervus elaphus
#
#                                         common_names conservation_status
# 0                           Gapper's Red-Backed Vole                 NaN
# 1                              American Bison, Bison                 NaN
# 2  Aurochs, Aurochs, Domestic Cattle (Feral), Dom...                 NaN
# 3  Domestic Sheep, Mouflon, Red Sheep, Sheep (Feral)                 NaN
# 4                                      Wapiti Or Elk                 NaN

# %%
# Let's assess the frequency of animal by category

sns.violinplot(observations.park_name, observations.observations)
plt.show
# Out:
# /Users/nicholaslambert/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# How many of each category of animal have a conservation status
# Out:
# /Users/nicholaslambert/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-527eeb09452c> in <module>
#       1 # How many of each category of animal have a conservation status
#       2
# ----> 3 sns.barplot(species.category, species.conservation_status)
#       4 plt.show()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
# ...
